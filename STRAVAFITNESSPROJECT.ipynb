# %% [markdown]
# <a href="https://colab.research.google.com/github/GopiNikhil/Strava-Fitness-/blob/main/STRAVAFITNESSPROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - STRAVA FITNESS PROJECT

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# To analyze daily, hourly, and minute-level Fitbit activity data to understand user behavior patterns and generate actionable insights that help improve user health engagement and drive positive business impact.
# 📁 Datasets Used:
#
#     daily_level.csv – Summary of daily activity per user.
#
#     hourly_level.csv – Hourly data on steps and calories.
#
#     minute_level.csv – Minute-by-minute intensity and step data.
#
# 🛠️ Tools & Libraries:
#
#     Python, Pandas – Data loading and manipulation
#
#     Matplotlib, Seaborn – Data visualization
#
#     NumPy – Statistical calculations
#
# 📈 Visualizations Created:
#
#     Bar Charts – Average steps and calories across weekdays
#
#     Line Charts – Hourly trends in calories and steps
#
#     Pie & Donut Charts – Distribution of activity intensity (e.g., very active vs. sedentary)
#
#     Histogram – Distribution of daily steps among users
#
# 🔍 Key Insights:
#
#     Users are most active between morning and evening hours.
#
#     Sedentary behavior dominates a large portion of the day.
#
#     There's a significant drop in VeryActiveMinutes compared to other categories.
#
#     Calories burned correlate with total steps and active time.
#
# 💡 Recommendations:
#
#     Implement personalized goals and fitness challenges based on user activity profiles.
#
#     Introduce sedentary alerts to reduce inactive time.
#
#     Use visual dashboards to give users real-time feedback and motivation.
#
#     Reward consistent progress to build healthy habits.
#
# ✅ Conclusion:
#
# By leveraging detailed activity data and insightful visualizations, the project provides clear strategies to engage users, promote better health habits, and ultimately drive long-term app usage and satisfaction.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In today’s fast-paced world, maintaining a healthy lifestyle is a challenge for many individuals. Despite the widespread use of fitness trackers like Fitbit, users often struggle to interpret their data in meaningful ways that lead to long-term behavioral change. Additionally, businesses offering these health and wellness tools face difficulties in understanding user behavior trends, identifying engagement gaps, and providing timely, personalized interventions that truly help users improve their health.
#
# The challenge is two-fold:
#
#     From the user perspective: There is a lack of clear, actionable feedback from the data collected, making it hard for users to stay motivated and improve their activity levels consistently.
#
#     From the business perspective: Companies need to identify when and how users are active or sedentary, determine what drives engagement, and use this insight to create impactful health programs, improve user retention, and deliver value through personalized experiences.
#
# Therefore, the problem is:
#
#     How can Fitbit activity data (daily, hourly, and minute-level) be analyzed to uncover meaningful patterns in user behavior and generate insights that support personalized engagement strategies, promote healthier habits, and help achieve positive business outcomes?
#
# This project aims to solve this problem by using data visualization and statistical analysis to:
#
#     Understand how users move and behave throughout the day and week,
#
#     Identify periods of high and low activity,
#
#     Highlight opportunities for intervention,
#
#     And provide strategic recommendations to enhance user experience and app effectiveness.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
daily_df = pd.read_csv('daily_level.csv')
daily_df.columns = daily_df.columns.str.replace('"', '').str.strip()
hourly_df = pd.read_csv('hourly_level.csv')
minute_df = pd.read_csv('minute_level.csv')
print("Datasets loaded successfully.\n")
# Out:
# Datasets loaded successfully.

# %% [markdown]
# ### Dataset FirstView

# %%
# Preview
print("First 5 rows of the merged dataset: Daily Level")
display(daily_df.head())
print("First 5 rows of the merged dataset: Hourly Level")
display(hourly_df.head())
print("First 5 rows of the merged dataset: Minute Level")
display(minute_df.head())
# Out:
# First 5 rows of the merged dataset: Daily Level
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   04-12-2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0                1.88                      0.55
# 1                         0                1.57                      0.69
# 2                         0                2.44                      0.40
# 3                         0                2.14                      1.26
# 4                         0                2.71                      0.41
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows, columns = daily_df.shape
print(f"The daily_level dataset contains {rows} rows and {columns} columns.")

rows, columns = hourly_df.shape
print(f"The hourly_level dataset contains {rows} rows and {columns} columns.")

rows, columns = minute_df.shape
print(f"The minute_level dataset contains {rows} rows and {columns} columns.")
# Out:
# The daily_level dataset contains 940 rows and 15 columns.
# The hourly_level dataset contains 22099 rows and 6 columns.
# The minute_level dataset contains 3258 rows and 7 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Dataset Information:")
daily_df.info()
hourly_df.info()
minute_df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    int64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    int64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#     DAILY LEVEL
#
#     Granularity: 1 row per user per day
#
#     Date column: ActivityDate
#
#     Key metrics:
#
#         TotalSteps: Total steps taken
#
#         TotalDistance: Total distance covered
#
#         VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes: Time spent at different activity levels
#
#         Calories: Calories burned
#
# ✅ Use cases: Daily activity trends, correlation analysis, weekly patterns, activity intensity.Answer Here
# # -------------------------------------------------------------------
#     HOURLY LEVEL
#
#     Granularity: 1 row per user per hour
#
#     DateTime column: ActivityHour
#
#     Key metrics:
#
#         StepTotal: Steps taken during that hour
#
#         Calories: Calories burned during that hour
#
#         TotalIntensity, AverageIntensity: Measures of movement effort
#
# ✅ Use cases: Peak activity hours, hourly behavior, circadian rhythm, daily calorie profile.
#
# #--------------------------------------------------------------------
#     MINUTE LEVEL
#
#     Granularity: 1 row per user per minute
#
#     DateTime column: ActivityMinute
#
#     Key metrics:
#
#         StepTotal: Steps taken during that minute
#
#         Likely very sparse in data (many 0 values)
#
# ✅ Use cases: Micro-activity patterns, short bursts of movement, step spikes.

# %% [markdown]
# ## ***2. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1: Average Steps by Day of Week(Daily Level)

# %%
# Chart - 1 visualization code
# Ensure the column is datetime and reassign
daily_df['ActivityDate'] = pd.to_datetime(daily_df['ActivityDate'], errors='coerce')

# Now safely extract the day name
daily_df['Day'] = daily_df['ActivityDate'].dt.day_name()

# Plot average total steps by weekday
plt.figure(figsize=(10, 6))
sns.barplot(data=daily_df, x='Day', y='TotalSteps', estimator='mean', order=[
    'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'
])
plt.title('Average Total Steps by Day of Week')
plt.ylabel('Average Steps')
plt.xlabel('Day')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart reveals daily behavior patterns — are users more active on weekends or weekdays?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Users typically walk more on weekends, especially Saturday and Sunday, suggesting they are less active during workdays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This insight helps fitness app designers:
#
#     Schedule push notifications, challenges, or reminders during low-activity weekdays.
#
#     Promote weekend walking goals or social challenges to maintain momentum.

# %% [markdown]
# #### Chart - 2: Calories vs. Steps Scatter Plot(Daily Level)

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 6))
sns.scatterplot(data=daily_df, x='TotalSteps', y='Calories', hue='Day', palette='viridis')
plt.title('Calories vs Total Steps')
plt.xlabel('Total Steps')
plt.ylabel('Calories Burned')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand the relationship between calories burned and steps taken.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a positive correlation — more steps generally lead to higher calories burned, though with some variation due to other factors (e.g., intensity or duration).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Tailoring fitness goals based on user calorie/step targets.
#
# Educating users that consistent movement (not necessarily intense workouts) drives calorie burn.

# %% [markdown]
# #### Chart - 3: Sedentary Minutes Distribution(Daily Level)

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(data=daily_df, x='SedentaryMinutes', bins=20, kde=True, color='coral')
plt.title('Distribution of Sedentary Minutes')
plt.xlabel('Sedentary Minutes')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Sedentary behavior is a critical risk factor for poor health. This chart shows how much time users remain inactive.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Many users have a high number of sedentary minutes, often well over 500–600 minutes (~8–10 hours per day).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Reminders to stand or stretch regularly.
#
# Alerts when prolonged inactivity is detected.
#
# Development of personalized movement prompts.

# %% [markdown]
# #### Chart - 4: Average Calories Burnt by Hour of Day(Hourly Level Plot)

# %%
# Chart - 4 visualization code
# Force datetime parsing again in case it's been dropped
hourly_df['ActivityHour'] = pd.to_datetime(hourly_df['ActivityHour'], errors='coerce')
hourly_df['Hour'] = hourly_df['ActivityHour'].dt.hour

# Prepare data for plotting
avg_calories_per_hour = hourly_df.groupby('Hour')['Calories'].mean().reset_index()

# Use non-interactive backend to prevent crashes
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_calories_per_hour, x='Hour', y='Calories', marker='o', color='teal')
plt.title('Average Calories Burned by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Calories')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify when users are most active (in terms of energy expenditure) during the day.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Peak calorie burn happens between morning and early evening hours, with a dip during early afternoon and night.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Target time-based activity nudges (e.g., mid-day stretch reminders).
#
# Optimize ad placement or motivational content during high/low activity windows.

# %% [markdown]
# #### Chart - 5: Boxplot of Calories by Hour(Hourly Level Plot)

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12, 6))
sns.boxplot(data=hourly_df, x='Hour', y='Calories')
plt.title('Calories Distribution by Hour')
plt.xlabel('Hour')
plt.ylabel('Calories')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show variability in calorie burn across different hours — not just averages, but also outliers and spread.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High variability during daytime hours, lower during sleep hours (late night to early morning).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Supports:
#
#     Personalized workout time recommendations (e.g., "You burn most at 6 PM").
#
#     Segmented user targeting (e.g., night-shift workers vs day workers).

# %% [markdown]
# #### Chart - 6: Total Steps Per Minute (Distribution)(Minute Level Plot)

# %%
# Chart - 6 visualization code

# Ensure datetime
minute_df['ActivityHour'] = pd.to_datetime(minute_df['ActivityHour'], errors='coerce')

# Plot distribution of TotalSteps
plt.figure(figsize=(10, 6))
sns.histplot(minute_df['TotalSteps'], bins=30, kde=True, color='dodgerblue')
plt.title('Distribution of Steps Per Minute')
plt.xlabel('Steps in One Minute')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-92-1290806824>:4: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   minute_df['ActivityHour'] = pd.to_datetime(minute_df['ActivityHour'], errors='coerce')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show how frequently users are moving intensely within 1-minute intervals.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most 1-minute intervals show 0–20 steps, indicating light or sedentary behavior dominates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Helps create step streak or micro-goals (e.g., “Take 25 steps every 5 minutes”) to fight sedentary habits.

# %% [markdown]
# #### Chart - 7:  Total Steps by Hour (Minute-level Aggregation)(Minute Level Plot)

# %%
# Chart - 7 visualization code
# Extract hour
minute_df['Hour'] = minute_df['ActivityHour'].dt.hour

# Sum steps per hour
steps_by_hour = minute_df.groupby('Hour')['TotalSteps'].sum().reset_index()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=steps_by_hour, x='Hour', y='TotalSteps', palette='coolwarm')
plt.title('Total Steps by Hour (Aggregated from Minute-Level Data)')
plt.xlabel('Hour of Day')
plt.ylabel('Total Steps')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-93-2485225669>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=steps_by_hour, x='Hour', y='TotalSteps', palette='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand when people accumulate the most steps — granular pattern of movement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Steps cluster during morning and evening (commute/exercise), with mid-day dips.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Design timed interventions:
#
#     Send stretch/move alerts during dip hours.
#
#     Schedule group step challenges around peak activity windows.

# %% [markdown]
# #### Chart - 8: Number of Active Minutes Per Hour(Minute Level Plot)

# %%
# Chart - 8 visualization code
# Filter for active minutes (non-zero steps)
active_minutes = minute_df[minute_df['TotalSteps'] > 0]

# Count active minutes per hour
active_minute_count = active_minutes.groupby('Hour').size().reset_index(name='ActiveMinutes')

# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=active_minute_count, x='Hour', y='ActiveMinutes', marker='o', color='seagreen')
plt.title('Number of Active Minutes Per Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Active Minutes')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To track how many minutes per hour users are actually active (i.e., not sitting still).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Only a few minutes per hour are active, suggesting opportunity for more consistent movement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Introduce “10 active minutes per hour” goals.
#
# Design progress badges for consistency (e.g., “You moved every hour today!”)

# %% [markdown]
# #### Chart - 9: Average Daily Minutes by Activity Category(Daily Level Plot)

# %%
# Chart - 9 visualization code

# Donut Chart for Average Minutes
avg_minutes = daily_df[['VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes']].mean()

plt.figure(figsize=(8, 6))
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
plt.pie(avg_minutes, labels=avg_minutes.index, autopct='%1.1f%%', startangle=140,
        colors=colors, wedgeprops={'width': 0.4})
plt.title('Average Daily Minutes by Activity Category (Donut Chart)')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A donut chart effectively communicates the proportion of time spent in different activity categories in a visually intuitive and engaging way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The largest share of time is spent in SedentaryMinutes, followed by LightlyActiveMinutes. Very few minutes are spent in VeryActive or FairlyActive categories. This indicates a predominantly sedentary lifestyle for most users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. These insights help:
#
#     Design more engaging workout challenges in mobile health apps.
#
#     Trigger sedentary alerts or reminders to stand or move.
#
#     Offer personalized fitness programs encouraging increased Very Active minutes, which are more beneficial to health.

# %% [markdown]
# #### Chart - 10: Average Daily Distance by Activity Type(Daily Level Plot)

# %%
# Chart - 10 visualization code
# Calculate average distances
avg_distances = daily_df[['VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance']].mean()

# Pie Chart
plt.figure(figsize=(8, 6))
colors = ['#c2c2f0', '#ffb3e6', '#c4e17f', '#ffcc99']
plt.pie(avg_distances, labels=avg_distances.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Average Daily Distance by Activity Type (Pie Chart)')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart allows a quick comparison of distances by activity level, suitable when you want to see contribution by parts to a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# LightActiveDistance typically dominates, suggesting most movement comes from light-intensity activities.
#
# VeryActiveDistance is much lower, revealing fewer instances of intense physical activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Understanding how much of users' movement comes from low vs. high intensity can:
#
#     Inform goal setting in fitness tracking apps.
#
#     Help healthcare providers identify low-activity users and offer targeted advice.
#
#     Assist product managers in building features like distance streaks or step-based rewards to boost engagement.

# %% [markdown]
# ## 3. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Recommendations for the Client:
# 1. Personalize Activity Goals Based on User Segments
#
#     Use data like TotalSteps, VeryActiveMinutes, and Calories to group users into activity levels (e.g., sedentary, moderately active, highly active).
#
#     Set customized goals (steps, distance, active minutes) for each group.
#
# ✅ Business Value: Increases relevance and motivation, leading to higher app retention and healthier users.
# 2. Introduce Sedentary Behavior Alerts
#
#     The data shows high sedentary time across users (from the Donut Chart).
#
#     Implement smart notifications that encourage users to stand or stretch after prolonged inactivity.
#
# ✅ Business Value: Enhances user wellness and shows proactive care, improving customer trust.
# 3. Promote Very Active Minutes with Challenges
#
#     VeryActiveMinutes and Distance are significantly low.
#
#     Launch weekly challenges or rewards for reaching targets in this area.
#
# ✅ Business Value: Drives re-engagement and competition, boosting daily app use and physical activity.
# 4. Visual Feedback and Reports
#
#     Show users their activity breakdown (similar to pie/donut charts).
#
#     Compare their activity to past weeks or other users (leaderboards).
#
# ✅ Business Value: Keeps users informed and motivated, reducing churn.
# 5. Integrate Coaching or Tips Based on Data
#
#     For users with high SedentaryMinutes or low ActiveDistance, provide in-app fitness tips or micro-coaching.
#
# ✅ Business Value: Adds real value, differentiating the app from basic trackers.
# 6. Track Improvements Over Time
#
#     Encourage users to set small weekly improvements.
#
#     Show progress graphs for steps, calories, or active minutes.
#
# ✅ Business Value: Builds habit loops and fosters long-term retention.
# 💼 Final Note to the Client:
#
# Your data provides a powerful foundation to move from passive tracking to active behavior shaping. With a few enhancements using these insights, you can drive better health outcomes and business KPIs like user retention, engagement, and premium subscriptions.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of the Fitbit activity data from daily, hourly, and minute levels revealed key user behavior patterns and opportunities to enhance engagement and health outcomes.
# 🔍 Key Findings:
#
#     Most users spend a significant portion of their day sedentary, with limited Very Active Minutes.
#
#     Light activity and low-intensity distance dominate users’ movement profiles.
#
#     Calorie burn and steps align closely with active hours, peaking during morning and evening.
#
# 📈 Business Insights:
#
#     The low levels of intense physical activity suggest the need for targeted motivation and personalized fitness programs.
#
#     Visualizations like bar charts, pie/donut charts, and line plots helped highlight behavior patterns clearly and effectively.
#
#     There’s a strong opportunity to influence behavior positively through smart notifications, personalized goals, and activity challenges.
#
# 🧩 Recommendation Summary:
#
#     Personalize user goals based on activity levels.
#
#     Promote movement using challenges, rewards, and smart alerts.
#
#     Provide visual progress tracking and contextual tips to encourage consistent engagement.
#
# 🎯 Final Thought:
#
# By transforming raw activity data into actionable insights through strategic visualization and behavioral nudges, the business can not only increase user engagement but also improve health outcomes, aligning commercial goals with real-world wellness impact.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
